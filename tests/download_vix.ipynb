# %%
import yfinance as yf

def download_vix():
    #start_date = "yyyy-mm-dd"  # Inserisci la data di inizio desiderata
    #end_date = "yyyy-mm-dd"  # Inserisci la data di fine desiderata
    vix_data = yf.download("^VIX", period='60d')# start=start_date, end=end_date)
    return vix_data['Adj Close']

data = download_vix()

data
# Out:
# [*********************100%***********************]  1 of 1 completed
# Date
# 2023-03-07    19.590000
# 2023-03-08    19.110001
# 2023-03-09    22.610001
# 2023-03-10    24.799999
# 2023-03-13    26.520000
# 2023-03-14    23.730000
# 2023-03-15    26.139999
# 2023-03-16    22.990000
# 2023-03-17    25.510000
# 2023-03-20    24.150000
# 2023-03-21    21.379999
# 2023-03-22    22.260000
# 2023-03-23    22.610001
# 2023-03-24    21.740000
# 2023-03-27    20.600000
# 2023-03-28    19.969999
# 2023-03-29    19.120001
# 2023-03-30    19.020000
# 2023-03-31    18.700001
# 2023-04-03    18.549999
# 2023-04-04    19.000000
# 2023-04-05    19.080000
# 2023-04-06    18.400000
# 2023-04-10    18.969999
# 2023-04-11    19.100000
# 2023-04-12    19.090000
# 2023-04-13    17.799999
# 2023-04-14    17.070000
# 2023-04-17    16.950001
# 2023-04-18    16.830000
# 2023-04-19    16.459999
# 2023-04-20    17.170000
# 2023-04-21    16.770000
# 2023-04-24    16.889999
# 2023-04-25    18.760000
# ...
